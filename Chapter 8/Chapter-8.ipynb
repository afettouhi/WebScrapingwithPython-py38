# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

def getNgrams(content, n):
  content = content.split(' ')
  output = []
  for i in range(len(content)-n+1):
    output.append(content[i:i+n])
  return output

html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: '+str(len(ngrams)))
# Out:
# [['General-purpose,', 'high-level'], ['high-level', 'programming'], ['programming', 'language\n\n\nPythonParadigmMulti-paradigm:'], ['language\n\n\nPythonParadigmMulti-paradigm:', 'functional,'], ['functional,', 'imperative,'], ['imperative,', 'object-oriented,'], ['object-oriented,', 'structured,'], ['structured,', 'reflectiveDesigned\xa0byGuido'], ['reflectiveDesigned\xa0byGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirst\xa0appeared1990;'], ['FoundationFirst\xa0appeared1990;', '30\xa0years'], ['30\xa0years', 'ago\xa0(1990)[1]Stable'], ['ago\xa0(1990)[1]Stable', 'release3.8.6\n'], ['release3.8.6\n', ''], ['', ''], ['', '/'], ['/', '24\xa0September'], ['24\xa0September', '2020;'], ['2020;', '8\xa0days'], ['8\xa0days', 'ago\xa0(2020-09-24)[2]Preview'], ['ago\xa0(2020-09-24)[2]Preview', 'release3.9.0rc2\n'], ['release3.9.0rc2\n', ''], ['', ''], ['', '/'], ['/', '17\xa0September'], ['17\xa0September', '2020;'], ['2020;', '15\xa0days'], ['15\xa0days', 'ago\xa0(2020-09-17)[3]\nTyping'], ['ago\xa0(2020-09-17)[3]\nTyping', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'gradual'], ['gradual', '(since'], ['(since', '3.5)[4]OSLinux,'], ['3.5)[4]OSLinux,', 'macOS,'], ['macOS,', 'Windows'], ['Windows', 'Vista'], ['Vista', '(and'], ['(and', 'newer)'], ['newer)', 'and'], ['and', 'moreLicensePython'], ['moreLicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '3.5),[5]'], ['3.5),[5]', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '3.5)[6]Websitewww.python.orgMajor'], ['3.5)[6]Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'Jython,'], ['Jython,', 'RustPythonDialectsCython,'], ['RustPythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark[7]Influenced'], ['Starlark[7]Influenced', 'byABC,[8]'], ['byABC,[8]', 'Ada,[9]'], ['Ada,[9]', 'ALGOL'], ['ALGOL', '68,[10]'], ['68,[10]', 'APL,[11]'], ['APL,[11]', 'C,[12]'], ['C,[12]', 'C++,[13]'], ['C++,[13]', 'CLU,[14]'], ['CLU,[14]', 'Dylan,[15]'], ['Dylan,[15]', 'Haskell,[16]'], ['Haskell,[16]', 'Icon,[17]'], ['Icon,[17]', 'Java,[18]'], ['Java,[18]', 'Lisp,[19]'], ['Lisp,[19]', 'Modula-3,[13]'], ['Modula-3,[13]', 'Perl,'], ['Perl,', 'Standard'], ['Standard', 'ML[11]InfluencedApache'], ['ML[11]InfluencedApache', 'Groovy,'], ['Groovy,', 'Boo,'], ['Boo,', 'Cobra,'], ['Cobra,', 'CoffeeScript,[20]'], ['CoffeeScript,[20]', 'D,'], ['D,', 'F#,'], ['F#,', 'Genie,[21]'], ['Genie,[21]', 'Go,'], ['Go,', 'JavaScript,[22][23]'], ['JavaScript,[22][23]', 'Julia,[24]'], ['Julia,[24]', 'Nim,'], ['Nim,', 'Ring,[25]'], ['Ring,[25]', 'Ruby,[26]'], ['Ruby,[26]', 'Swift[27]\n'], ['Swift[27]\n', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks\n\nPython'], ['Wikibooks\n\nPython', 'is'], ['is', 'an'], ['an', 'interpreted,'], ['interpreted,', 'high-level'], ['high-level', 'and'], ['and', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'language.'], ['language.', 'Created'], ['Created', 'by'], ['by', 'Guido'], ['Guido', 'van'], ['van', 'Rossum'], ['Rossum', 'and'], ['and', 'first'], ['first', 'released'], ['released', 'in'], ['in', '1991,'], ['1991,', "Python's"], ["Python's", 'design'], ['design', 'philosophy'], ['philosophy', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'with'], ['with', 'its'], ['its', 'notable'], ['notable', 'use'], ['use', 'of'], ['of', 'significant'], ['significant', 'whitespace.'], ['whitespace.', 'Its'], ['Its', 'language'], ['language', 'constructs'], ['constructs', 'and'], ['and', 'object-orient ...
# 2-grams count is: 9361

# %%
import re

def getNgrams(content, n):
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    content = content.split(' ')
    content = [word for word in content if word != '']
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import string

def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == 'i')]
    return sentence

def cleanInput(content):
    content = content.upper()
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, "UTF-8")
    content = content.decode("ascii", "ignore")
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = []
    for sentence in content:
        ngrams.extend(getNgramsFromSentence(sentence, n))
    return(ngrams)

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
from collections import Counter

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = Counter()
    ngrams_list = []
    for sentence in content:
        newNgrams = [' '.join(ngram) for ngram in getNgramsFromSentence(sentence, n)]
        ngrams_list.extend(newNgrams)
        ngrams.update(newNgrams)
    return(ngrams)

# %%
print(getNgrams(content, 2))
# Out:
# Counter({'PYTHON SOFTWARE': 42, 'SOFTWARE FOUNDATION': 41, 'OF THE': 37, 'IN PYTHON': 32, 'OF PYTHON': 26, 'IN THE': 25, 'FROM THE': 25, 'VAN ROSSUM': 23, 'THE PYTHON': 21, 'RETRIEVED FEBRUARY': 21, 'AS A': 20, 'SUCH AS': 20, 'RETRIEVED NOVEMBER': 17, 'ARCHIVED FROM': 17, 'THE ORIGINAL': 17, 'TO THE': 15, 'PYTHON ENHANCEMENT': 15, 'ORIGINAL ON': 15, 'PYTHON IS': 14, 'RETRIEVED SEPTEMBER': 14, 'ENHANCEMENT PROPOSALS': 14, 'RETRIEVED JUNE': 14, 'PROGRAMMING LANGUAGE': 13, 'IS A': 13, 'CAN BE': 13, 'BE USED': 13, 'RETRIEVED MARCH': 13, 'OF A': 12, 'IT IS': 12, 'FOR PYTHON': 11, 'FOR EXAMPLE': 11, 'ROSSUM GUIDO': 11, 'RETRIEVED APRIL': 11, 'RETRIEVED JANUARY': 11, 'GUIDO VAN': 10, 'STANDARD LIBRARY': 10, 'OTHER LANGUAGES': 10, 'TO PYTHON': 10, 'RETRIEVED MAY': 10, 'RETRIEVED DECEMBER': 10, 'AND A': 9, 'SYNTAX AND': 9, 'WITH THE': 9, 'FOR THE': 9, 'AS THE': 9, 'TO BE': 9, 'PROGRAMMING LANGUAGES': 9, 'STATEMENT WHICH': 9, 'USED TO': 9, 'FROM PYTHON': 9, 'RETRIEVED JULY': 9, 'THE LANGUAGE': 8, 'IS THE': 8, 'PYTHON AND': 8, 'TO A': 8, 'ON THE': 8, 'MACHINE LEARNING': 8, 'RETRIEVED AUGUST': 8, 'THE STANDARD': 7, 'WRITTEN IN': 7, 'THE SAME': 7, 'PART OF': 7, 'PYTHON HAS': 7, 'COMPILES PYTHON': 7, 'PYTHON TO': 7, 'PYTHON FOR': 7, 'FREE SOFTWARE': 7, 'USE OF': 6, 'IS NOT': 6, 'PYTHON CODE': 6, 'REFERENCE IMPLEMENTATION': 6, 'OF ITS': 6, 'MANY OTHER': 6, 'PYTHON USES': 6, 'WITH A': 6, 'A PYTHON': 6, 'IN A': 6, 'IS USED': 6, 'USED IN': 6, 'ARE NOT': 6, 'SCRIPTING LANGUAGE': 6, 'SCIENTIFIC COMPUTING': 6, 'COMPARISON OF': 6, 'STACKLESS PYTHON': 5, 'LANGUAGE THAT': 5, 'DOES NOT': 5, 'ON PYTHON': 5, 'AND SEMANTICS': 5, 'NEW FEATURES': 5, 'OBJECT-ORIENTED PROGRAMMING': 5, 'IT ALSO': 5, 'BETTER THAN': 5, 'LANGUAGES SUCH': 5, 'MONTY PYTHON': 5, 'CODE IS': 5, "EDIT PYTHON'S": 5, 'BY THE': 5, 'THERE ARE': 5, 'INTEGER DIVISION': 5, 'USED AS': 5, 'AND THE': 5, 'CAN CONTAIN': 5, 'CONTAIN MIXED': 5, 'MIXED TYPES': 5, 'AND IS': 5, 'PYTHON AS': 5, 'A SIMILAR': 5, 'A SCRIPTING': 5, 'PEP PYTHON': 5, 'RETRIEVED OCTOBER': 5, 'RELEASED IN': 4, 'FUNCTIONAL PROGRAMMING': 4, 'LIST COMPREHENSIONS': 4, 'THAT IS': 4, 'PYTHON LANGUAGE': 4, 'AND PYTHON': 4, 'THE LAST': 4, 'WITH PYTHON': 4, 'DEVELOPMENT ENVIRONMENTS': 4, 'SEE ALSO': 4, 'MAIN ARTICLE': 4, 'ON DECEMBER': 4, 'EDIT PYTHON': 4, 'IT HAS': 4, 'IS BETTER': 4, 'RATHER THAN': 4, 'IN CONTRAST': 4, 'PYTHON INTERPRETER': 4, "OF PYTHON'S": 4, 'FROM A': 4, 'LIKE A': 4, 'MAY BE': 4, 'BLOCK OF': 4, 'OF CODE': 4, 'THE CLASS': 4, 'WHICH IS': 4, 'THEY ARE': 4, 'FLOOR DIVISION': 4, 'THE OPERATOR': 4, 'OPERATOR FOR': 4, 'THE SYNTAX': 4, 'JAVA AND': 4, 'THAT THE': 4, 'A NEW': 4, 'KINDS OF': 4, 'QUOTE MARKS': 4, 'PERL AND': 4, 'USE THE': 4, 'PYTHON A': 4, 'USED FOR': 4, 'SEQUENCE OF': 4, 'FLOATING POINT': 4, 'EXAMPLE THE': 4, 'WEB SERVER': 4, 'A FEW': 4, 'LATEST RELEASE': 4, 'RELEASE IN': 4, 'IN AND': 4, 'THE VERSION': 4, 'VERSION NUMBER': 4, 'NUMBER IS': 4, 'IS INCREMENTED': 4, 'ARTIFICIAL INTELLIGENCE': 4, 'PYTHON INSIDER': 4, "WHAT'S NEW": 4, 'NEW IN': 4, 'IN SCIENCE': 4, 'PYTHON PROGRAMMING': 3, "PYTHON'S DESIGN": 3, 'DESIGN PHILOSOPHY': 3, 'PYTHON WAS': 3, 'REFERENCE COUNTING': 3, 'WAS A': 3, 'A MAJOR': 3, 'WILL BE': 3, 'ARE SUPPORTED': 3, 'AVAILABLE FOR': 3, 'OPERATING SYSTEMS': 3, 'AND OPEN-SOURCE': 3, 'FEATURES AND': 3, 'AND PHILOSOPHY': 3, 'CONTROL FLOW': 3, 'TO OTHER': 3, 'API DOCUMENTATION': 3, 'DOCUMENTATION GENERATORS': 3, 'PYTHON PYTHON': 3, 'THE PROJECT': 3, "AS PYTHON'S": 3, "PYTHON'S BENEVOLENT": 3, 'BENEVOLENT DICTATOR': 3, 'DICTATOR FOR': 3, 'FOR LIFE': 3, 'PYTHON COMMUNITY': 3, 'STEERING COUNCIL': 3, 'WAS RELEASED': 3, 'SUPPORT FOR': 3, 'IT WAS': 3, 'MANY OF': 3, 'A LARGE': 3, 'TYPING AND': 3, "THE LANGUAGE'S": 3, 'LARGE STANDARD': 3, 'CONTRAST TO': 3, 'THERE IS': 3, 'TO DO': 3, 'THE CPYTHON': 3, 'IS ALSO': 3, 'THIS IS': 3, 'A COMMON': 3, 'THAT IT': 3, 'USES PYTHON': 3, 'EDIT MAIN': 3, 'PYTHON SYNTAX': 3, 'AND IT': 3, 'ASSIGNMENT STATEMENT': 3, 'NATURE OF': 3, 'NAME IS': 3, 'USING THE': 3, 'DATA TYPE': 3,  ...
# <ipython-input-3-e4883bda7aa9>:14: FutureWarning: Possible nested set at position 3
#   content = re.sub('\n|[[\d+\]]', ' ', content)
